# %%
import pandas as pd
file_path = "./ref/청소년정신건강20250304.csv"
ori = pd.read_csv(file_path)
ori
# Out:
#      시점 스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2 자살 생각률  \
# 0    시점       전체        남학생        여학생      전체       남학생       여학생     전체
# 1  2024     45.3       39.6       51.3    28.2      23.9      32.6   14.2
#
#   자살 생각률.1 자살 생각률.2
# 0      남학생      여학생
# 1     11.1     17.4

# %%
new_name = ['시점','스트레스','스트레스남학생','스트레스여학생','우울감경험율','우울남학생','우울여학생','자살생각율','자살남학생','자살여학생']
ori.columns = new_name
ori
# Out:
#      시점  스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 0    시점    전체     남학생     여학생     전체   남학생   여학생    전체   남학생   여학생
# 1  2024  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4

# %%
ori=ori.loc[1:,'스트레스':]
ori
# Out:
#    스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 1  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4

# %%
ori.loc[2] = 100-ori.loc[1,'스트레스':].astype(float)
ori['응답'] = ['그렇다','아니다']
ori
# Out:
#    스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생   응답
# 1  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4  그렇다
# 2  54.7    60.4    48.7   71.8  76.1  67.4  85.8  88.9  82.6  아니다

# %%
ori=ori.set_index('응답')
ori
# Out:
#      스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 응답
# 그렇다  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4
# 아니다  54.7    60.4    48.7   71.8  76.1  67.4  85.8  88.9  82.6

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm
fontlist = fm.findSystemFonts(fontpaths=None, fontext='ttf')
fontlist
# Out:
# ['C:\\Windows\\Fonts\\FRABKIT.TTF',
#  'C:\\Windows\\Fonts\\ARLRDBD.TTF',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\ARIALNBI.TTF',
#  'C:\\Windows\\Fonts\\LSANS.TTF',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\comicbd.ttf',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\LTYPEO.TTF',
#  'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\Windows\\Fonts\\GOUDYSTO.TTF',
#  'C:\\Windows\\Fonts\\ANTQUAI.TTF',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\simsun.ttc',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\HANDotumExt.ttf',
#  'C:\\Windows\\Fonts\\TEMPSITC.TTF',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\ARIALNB.TTF',
#  'C:\\Windows\\Fonts\\PARCHM.TTF',
# ...

# %%
path =  'C:\\Windows\\Fonts\\NanumGothic.ttf'
font_name = fm.FontProperties(fname=path).get_name()
rc('font',family=font_name)
plt.text(0.3,0.3,'한글',size=50)
# Out:
# Text(0.3, 0.3, '한글')

# %%
ori['스트레스'].astype(float).plot.pie(explode= [0,0.02])
# Out:
# <Axes: ylabel='스트레스'>

# %%
fig, ax = plt.subplots(1,3,figsize=(10,8))

ori['스트레스'].astype(float).plot.pie(explode= [0,0.02],ax=ax[0],autopct="%1.1f%%")
ax[0].set_title('스트레스를 받은 적이 있다.')
ax[0].set_ylabel('')

fig, ax = plt.subplots(1,3,figsize=(10,8))
ori['우울감경험율'].astype(float).plot.pie(explode= [0,0.02],ax=ax[0],autopct="%1.1f%%")
ax[0].set_title('우울증을 받은 적이 있다.')
ax[0].set_ylabel('')

fig, ax = plt.subplots(1,3,figsize=(10,8))
ori['자살생각율'].astype(float).plot.pie(explode= [0,0.02],ax=ax[0],autopct="%1.1f%%")
ax[0].set_title('자살생각을 한 적이 있다.')
ax[0].set_ylabel('')

plt.show()

# %%
import pandas as pd
file_path = "ref/청소년개인위생20250304.csv"
ori = pd.read_csv(file_path)
ori
# Out:
#      시점 식사전 비누이용 손씻기 실천율 식사전 비누이용 손씻기 실천율.1 식사전 비누이용 손씻기 실천율.2  \
# 0    시점             학교에서               학교에서               학교에서
# 1    시점               소계                남학생                여학생
# 2  2024             44.1               46.8               41.2
#
#   식사전 비누이용 손씻기 실천율.3 식사전 비누이용 손씻기 실천율.4 식사전 비누이용 손씻기 실천율.5  \
# 0                집에서                집에서                집에서
# 1                 소계                남학생                여학생
# 2               62.6               65.7               59.4
#
#   화장실 사용후 비누이용 손씻기 실천율 화장실 사용후 비누이용 손씻기 실천율.1 화장실 사용후 비누이용 손씻기 실천율.2  \
# 0                 학교에서                   학교에서                   학교에서
# 1                   소계                    남학생                    여학생
# 2                 89.0                   86.1                   92.1
#
#   화장실 사용후 비누이용 손씻기 실천율.3 화장실 사용후 비누이용 손씻기 실천율.4 화장실 사용후 비누이용 손씻기 실천율.5
# 0                    집에서                    집에서                    집에서
# ...

# %%
new_name = ['시점','식사전학교비누실천율','식사전학교남자비누실천율','식사전학교여자비누실천율','식사전집비누실천율','식사전집비누남자실천율','식사전집비누여자실천율','화장실사용후학교실천율','화장실사용후학교실천율남자','화장실사용후학교실천율여자','화장실사용후집실천율','화장실사용후집실천율남자','화장실사용후집실천율여자']
ori.columns = new_name
ori
# Out:
#      시점 식사전학교비누실천율 식사전학교남자비누실천율 식사전학교여자비누실천율 식사전집비누실천율 식사전집비누남자실천율  \
# 0    시점       학교에서         학교에서         학교에서       집에서         집에서
# 1    시점         소계          남학생          여학생        소계         남학생
# 2  2024       44.1         46.8         41.2      62.6        65.7
#
#   식사전집비누여자실천율 화장실사용후학교실천율 화장실사용후학교실천율남자 화장실사용후학교실천율여자 화장실사용후집실천율 화장실사용후집실천율남자  \
# 0         집에서        학교에서          학교에서          학교에서        집에서          집에서
# 1         여학생          소계           남학생           여학생         소계          남학생
# 2        59.4        89.0          86.1          92.1       87.4         86.6
#
#   화장실사용후집실천율여자
# 0          집에서
# 1          여학생
# 2         88.2

# %%
ori=ori.loc[2:,'식사전학교비누실천율':]
ori
# Out:
#   식사전학교비누실천율 식사전학교남자비누실천율 식사전학교여자비누실천율 식사전집비누실천율 식사전집비누남자실천율 식사전집비누여자실천율  \
# 2       44.1         46.8         41.2      62.6        65.7        59.4
#
#   화장실사용후학교실천율 화장실사용후학교실천율남자 화장실사용후학교실천율여자 화장실사용후집실천율 화장실사용후집실천율남자 화장실사용후집실천율여자
# 2        89.0          86.1          92.1       87.4         86.6         88.2

# %%
import pandas as pd
df = pd.DataFrame([
    ['20210901', 'A',   1],
    ['20210901', 'B',  10],
    ['20210901', 'C', 100],
    ['20210902', 'A' ,  2],
    ['20210902', 'B',  20],
    ['20210902', 'C', 200],
    ['20210903', 'A',   3],
    ['20210903', 'B',  30],
    ['20210903', 'C', 300],
    
], columns = ['date','type', 'volume'])
df
# Out:
#        date type  volume
# 0  20210901    A       1
# 1  20210901    B      10
# 2  20210901    C     100
# 3  20210902    A       2
# 4  20210902    B      20
# 5  20210902    C     200
# 6  20210903    A       3
# 7  20210903    B      30
# 8  20210903    C     300

# %%
pivot1 = df.pivot(index='date',columns='type',values='volume')
pivot1
# Out:
# type      A   B    C
# date
# 20210901  1  10  100
# 20210902  2  20  200
# 20210903  3  30  300

# %%
pivot1.columns=pivot1.columns.values
pivot1
# Out:
#           A   B    C
# date
# 20210901  1  10  100
# 20210902  2  20  200
# 20210903  3  30  300

# %%
pivot1.reset_index(level=0,inplace=True)
pivot1
# Out:
#    index      date  A   B    C
# 0      0  20210901  1  10  100
# 1      1  20210902  2  20  200
# 2      2  20210903  3  30  300

# %%
pivot1 = pivot1.set_index('date')
pivot1
# Out:
#           index  A   B    C
# date
# 20210901      0  1  10  100
# 20210902      1  2  20  200
# 20210903      2  3  30  300

# %%
import matplotlib.pyplot as plt
fig , ax = plt.subplots(1,2)
fig.set_size_inches(20,8)
pivot1.plot(kind='bar',ax=ax[0])
pivot1.plot(kind='barh',ax=ax[1])
# Out:
# <Axes: ylabel='date'>

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame({
    '지역':['안동','안동','안동','경기',
         '경기','부산','서울','안동'],
    '요일': ['월','월','수','월','화',
          '월','목','금'],
    '강수확률':[80,70,90,10,20,30,40,80],
    '강수량':[80,50,100,200,200,100,50,1000]})
df
# Out:
#    지역 요일  강수확률   강수량
# 0  안동  월    80    80
# 1  안동  월    70    50
# 2  안동  수    90   100
# 3  경기  월    10   200
# 4  경기  화    20   200
# 5  부산  월    30   100
# 6  서울  목    40    50
# 7  안동  금    80  1000

# %%
pd.pivot_table(df,index='요일',
              columns='지역',
              aggfunc='max')
# Out:
#       강수량                       강수확률
# 지역     경기     부산    서울      안동    경기    부산    서울    안동
# 요일
# 금     NaN    NaN   NaN  1000.0   NaN   NaN   NaN  80.0
# 목     NaN    NaN  50.0     NaN   NaN   NaN  40.0   NaN
# 수     NaN    NaN   NaN   100.0   NaN   NaN   NaN  90.0
# 월   200.0  100.0   NaN    80.0  10.0  30.0   NaN  80.0
# 화   200.0    NaN   NaN     NaN  20.0   NaN   NaN   NaN

# %%
pd.pivot_table(df,index='요일',
              columns='지역',
              aggfunc='max') .fillna(' ')
# Out:
#       강수량                       강수확률
# 지역     경기     부산    서울      안동    경기    부산    서울    안동
# 요일
# 금                       1000.0                    80.0
# 목                 50.0                      40.0
# 수                        100.0                    90.0
# 월   200.0  100.0          80.0  10.0  30.0        80.0
# 화   200.0                       20.0

# %%
data = {
    "도시": ["서울", "부산", "서울", "부산", "대구", "대구","대구"],
    "연도": [2022, 2022, 2023, 2023, 2022, 2023, 2023],
    "판매량": [100, 80, 120, 90, 70, 60, 0]
}
df = pd.DataFrame(data)
pivot = df.pivot_table(index="도시", columns="연도", values="판매량",aggfunc="min", fill_value=0)
#df
pivot
# Out:
# 연도  2022  2023
# 도시
# 대구    70     0
# 부산    80    90
# 서울   100   120

# %% [markdown]
# 데이터 상으로는 2024년도의 학생보다 2025년도의 학생의 정신건강 상태가 더 나쁜것으로 확인할 수 있음.
# 데이터의 변화폭이 큰것은 아니지만 증가하는 모습을 보이기 때문에 정소년의 정신건강에 대해 관심을 가져야 함.
# 정소년의 자살고민율은 과거에 비해 0.3% 하락한 모습을 보이지만 기본적으로 14.5%라는 수치를 가지고 있어
# 청소년들도 상담과 정신건강 체크를 통해 큰 관심을 가져야 한다고 생각함.
